# %%
! pip install suffix_trees langdetect
# Out:
# Requirement already satisfied: suffix_trees in /Users/jonharris/python-environments/pytorch/lib/python3.9/site-packages (0.3.0)
# Requirement already satisfied: langdetect in /Users/jonharris/python-environments/pytorch/lib/python3.9/site-packages (1.0.9)
# Requirement already satisfied: six in /Users/jonharris/python-environments/pytorch/lib/python3.9/site-packages (from langdetect) (1.16.0)

# %%
import re
from suffix_trees import STree          # used to determine longest similar string
import unicodedata
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option("display.max_columns", None)

# %%
# import jsons
def json2dict(path):
    x = pd.read_json(path)
    return dict(zip(x['id'], x['name']))


pbooktitle = json2dict('data/pbooktitle.json')
pbooktitlefull = json2dict('data/pbooktitlefull.json')
pjournal = json2dict('data/pjournal.json')
pjournalfull = json2dict('data/pjournalfull.json')
ptype = json2dict('data/ptype.json')

# import csvs
dblp = pd.DataFrame()
for i in range(1, 5):
    csv = pd.read_csv(f'data/dblp-{i}.csv')
    dblp = pd.concat([dblp, csv]).reset_index(drop=True)

test_hidden = pd.read_csv('data/test_hidden.csv')
train = pd.read_csv('data/train.csv')
validation_hidden = pd.read_csv('data/validation_hidden.csv')

# %% [markdown]
# # Data Cleaning

# %%
def remove_accents(s):
    '''
    https://docs.python.org/3/library/unicodedata.html#module-unicodedata
    '''
    s = str(s)      # cannot assume string
    norm_form = unicodedata.normalize('NFKD', s)
    return "".join([char for char in norm_form if not unicodedata.combining(char)])


def overlap_str(string1, string2):
    '''
    determine longest containing substring beteween strings
    '''
    return STree.STree([string1, string2]).lcs()


def sort_authors(s):
    '''
    sort authors by first name
    '''

    if '|' in s:
        authors = s.split(r'[|]')
        authors = [a.strip().title() for a in authors if a!='']
        authors = sorted(authors)
        s = '|'.join(authors)

    return s

# %%
df = dblp.copy()

# correct for negative publication years
df['pyear'] = df['pyear'].abs()

# remove accents for columns
df['pauthor'] = df['pauthor'].apply(remove_accents)
df['ptitle'] = df['ptitle'].apply(remove_accents)

# remove accents and joint dictionarys by key
ptype = {k: remove_accents(v) for k, v in ptype.items()}
pjournal = {k: remove_accents(v) for k, v in pjournal.items()}
pjournalfull = {k: remove_accents(v) for k, v in pjournalfull.items()}
pbooktitle = {k: remove_accents(v) for k, v in pbooktitle.items()}
pbooktitlefull = {k: remove_accents(v) for k, v in pbooktitlefull.items()}

# replace id keys with values
id_cols = ['ptype_id', 'pjournal_id', 'pjournalfull_id',
           'pbooktitle_id', 'pbooktitlefull_id']
for col in id_cols:
    df[col].replace(eval(col[:-3]), inplace=True)

# %%
# split pkey for further inspection
df['pkey_length'] = df['pkey'].str.count("/") + 1
df['pkey_split'] = df['pkey'].str.split('/')
df[['pkey_type', 'pkey_author']] = [[split[0], split[-1]]
                                    for split in df['pkey_split']]

# %%
# clean ptitle-pauthor switch
mask = df['ptitle'].str.contains('|', regex=False) | ((~df['pauthor'].str.contains('|', regex=False))
                                                                 & (df['pauthor'].str.len() > df['ptitle'].str.len()))
df.loc[mask, ['pauthor', 'ptitle']] = df.loc[mask, ['ptitle', 'pauthor']].values

# %%
# determine longest containing string to identify correct pauthor values
def get_lcs(str1,str2) -> str: return STree.STree([str1, str2]).lcs()

df['title_lcs_pkeyAuthor'] = df.apply(lambda x: get_lcs(x['ptitle'],x['pkey_author']), axis=1)
df['author_lcs_pkeyAuthor'] = df.apply(lambda x: get_lcs(x['pauthor'], x['pkey_author']), axis=1)

# %%
title_bettermatch = df['title_lcs_pkeyAuthor'].str.len(
) > df['author_lcs_pkeyAuthor'].str.len()
cols = ['pauthor', 'ptitle', 'pkey_author',
        'author_lcs_pkeyAuthor', 'title_lcs_pkeyAuthor']
df[ title_bettermatch  ][cols].sort_values(by='title_lcs_pkeyAuthor', key=lambda x: x.str.len(), ascending=False).head(30)
# Out:
#                                              pauthor  \
# 10683                                         Chart.
# 8450                                   Introduction.
# 8339                             PageRank Algorithm.
# 4006                                      Editorial.
# 12684                                 Geometric BIC.
# 6488                                      Editorial.
# 10731                                     Editorial.
# 16545                              Group morphology.
# 12747                                   Book review.
# 12634                                   Book review.
# 15275  On the Diophantine equation |axn - byn | = 1.
# 16768                               Electrolocation.
# 2019                               Retinal Displays.
# 2100                                        Modulus.
# 6461                                      Interface.
# 14898                                     Editorial.
# 8343                                    LIRVA virus.
# 6455                                       Ontology.
# 17071                                        Neuron.
# 3880                                   Book Reviews.
# 6051                                       Password.
# 17024                                     Editorial.
# 6422                                           Java.
# 12523                                  Logic Design.
# 14788                                Editor's Notes.
# 14914                                Editor's Notes.
# 6189                                      Editorial.
# 7632                                K-Klassen-Baume.
# 10630                                Editor's Notes.
# 16568                             John Robert Burger
#
#                                                   ptitle       pkey_author  \
# 10683                                  Hans Hinterberger    Hinterberger09
# 8450                                 Maris G. Martinsons      Martinsons05
# 8339                              Monika Rauch Henzinger       Henzinger08
# 4006                                      Alan Gilchrist       Gilchrist08
# 12684                                   Kenichi Kanatani        Kanatani10
# 6488                                    Michael Prietula        Prietula00
# 10731                                    Warren Harrison        Harrison98
# 16545                               J. B. T. M. Roerdink        Roerdink00
# 12747                                       Rene Henrion         Henrion07
# 12634                                    Joaquin Abellan         Abellan06
# 15275         Michael A. Bennett|Benjamin M. M. de Weger        BennettW98
# 16768                                 Maurice J. Chacron         Chacron07
# 2019                               Thomas A. Furness III         Furness02
# 2100                                       Scott Contini        Contini05c
# 6461                                 Patrick Th. Eugster         Eugster09
# 14898                                 Vincent Van Dongen          Dongen96
# 8343                                    Mark Fisher 0002          Fisher03
# 6455                                          Tom Gruber          Gruber09
# 17071                                  Rodolfo R. Llinas          Llinas08
# 3880                                     Martin R. Stytz          Stytz04b
# 6051                                        Gerald Brose          Brose05a
# 17024                                       Dan R. Olsen           Olsen94
# 6422                                       Michael Weber           Weber01
# 12523                                     Issam W. Damaj           Damaj08
# 14788                                   Margaret H. Eich           Eich88a
# 14914                                   Margaret H. Eich            Eich87
# 6189                                        Anil K. Jain           Jain94a
# 7632                                   Michael Lutz 0002            Lutz81
# 10630                                   Margaret H. Eich           Eich86a
# 16568  New Approachs to Quantum Computer Simulaton in...  quant-ph-0308158
#
#       author_lcs_pkeyAuthor title_lcs_pkeyAuthor
# 10683                     r         Hinterberger
# 8450                     ti           Martinsons
# 8339                     ge            Henzinger
# 4006                     ri            Gilchrist
# 12684                     t             Kanatani
# 6488                     ri             Prietula
# 10731                    ri             Harrison
# 16545                     r             Roerdink
# 12747                     o              Henrion
# 12634                     e              Abellan
# 15275                    ne              Bennett
# 16768                    ro              Chacron
# 2019                      e              Furness
# 2100                      o              Contini
# 6461                    ter              Eugster
# 14898                     o               Dongen
# 8343                      i               Fisher
# 6455                                      Gruber
# 17071                     n               Llinas
# 3880                                       Stytz
# 6051                      a                Brose
# 17024                     l                Olsen
# 6422                                       Weber
# 12523                     D                Damaj
# 14788                     E                 Eich
# 14914                     E                 Eich
# 6189                      i                 Jain
# 7632                      u                 Lutz
# 10630                     E                 Eich
# 16568                     h                 uant

# %%
# re-order authors -- may help with entity recognition?
df['pauthor'] = df['pauthor'].apply(sort_authors)

# %%
df
# Out:
#        Unnamed: 0                                            pauthor  peditor  \
# 0               4  Jorge Semiao|Juan J. Rodriguez-Andina|Fabian V...      NaN
# 1               7                                      Patrice Caire      NaN
# 2              10                         Sundeep B|Andrew Thangaraj      NaN
# 3              18                           Gerardo Pardo-Castellote      NaN
# 4              19  Ki-Hoon Lee|Kyu-Young Whang|Wook-Shin Han|Min-...      NaN
# ...           ...                                                ...      ...
# 17160        9975   Online bin packing with arbitrary release times.      NaN
# 17161        9978                    Chew Lim Tan|Henry Wai Kit Chia      NaN
# 17162        9981                 Sue Newell|Jacky Swan|Joseph Weiss      NaN
# 17163        9988  Martijn Hendriks|Barend Van Den Nieuwelaar|Fri...      NaN
# 17164        9990  Daniel J. Magenheimer|Liz Peters|Karl Pettis|D...      NaN
#
#                                                   ptitle  pyear  paddress  \
# 0      Improving the Tolerance of Pipeline Based Circ...   2007       NaN
# 1      A Normative Multi-Agent Systems Approach to th...   2007       NaN
# 2      Self-Orthogonality of q-Ary Images of qm-Ary C...   2007       NaN
# 3      OMG Data-Distribution Service: Architectural O...   2003       NaN
# 4      Ki-Hoon Lee|Kyu-Young Whang|Wook-Shin Han|Min-...   2009       NaN
# ...                                                  ...    ...       ...
# 17160   Online bin packing with arbitrary release times.   2008       NaN
# 17161  Neural Logic Network Learning using Genetic Pr...   2001       NaN
# 17162        Project Management: Minitrack Introduction.   2004       NaN
# 17163  Model checker aided design of a controller for...   2006       NaN
# 17164  Integer Multiplication and Division on the HP ...   1987       NaN
#
#       ppublisher pseries      pid                            pkey  \
# 0            NaN     NaN   180843          conf/dft/SemiaoRVSTT07
# 1            NaN     NaN   162991           conf/dagstuhl/Caire07
# 2            NaN     NaN  2261406               journals/tit/BT07
# 3            NaN     NaN   349720  conf/icdcsw/Pardo-Castellote03
# 4            NaN     NaN  1922328     journals/corr/abs-0911-4329
# ...          ...     ...      ...                             ...
# 17160        NaN     NaN  2245299             journals/tcs/ShiY08
# 17161        NaN     NaN   460233               conf/ijcai/TanC01
# 17162        NaN     NaN   289610           conf/hicss/NewellSW04
# 17163        NaN     NaN  2224414      journals/sttt/HendriksNV06
# 17164        NaN     NaN    62674    conf/asplos/MagenheimerPPZ87
#
#             ptype_id                              pjournal_id  \
# 0      inproceedings                                     None
# 1      inproceedings                                     None
# 2            article  IEEE Transactions on Information Theory
# 3      inproceedings                                     None
# 4            article                                     CoRR
# ...              ...                                      ...
# 17160        article                      Theor. Comput. Sci.
# 17161  inproceedings                                     None
# 17162  inproceedings                                     None
# 17163        article                                     STTT
# 17164  inproceedings                                     None
#
#                        pbooktitle_id  \
# 0                                DFT
# 1      Normative Multi-agent Systems
# 2                              WiMob
# 3                    ICDCS Workshops
# 4                               None
# ...                              ...
# 17160                           None
# 17161                          IJCAI
# 17162                          HICSS
# 17163                           None
# 17164                         ASPLOS
#
#                                          pjournalfull_id  \
# 0                                                   None
# 1                                                   None
# 2      International Journal of Ambient Computing and...
# 3                                                   None
# 4      International Journal of Wireless Information ...
# ...                                                  ...
# 17160      ACM Transactions on Computation Theory (TOCT)
# 17161                                               None
# 17162                                               None
# 17163                                                374
# 17164                                               None
#
#                                        pbooktitlefull_id  partition  \
# 0                                                    nan          1
# 1                               European Grid Conference          1
# 2      ACM Symposium on Parallel Algorithms and Archi...          1
# 3              International Agent Technology Conference          1
# 4                                                Messung          1
# ...                                                  ...        ...
# 17160                                            Messung          4
# 17161  inroads (ACM SIGCSE Bulletin)|ACM SIGCSE Bulletin          4
# 17162                     Grid and Cooperative Computing          4
# 17163                                            Messung          4
# 17164                                               1562          4
#
#        pkey_length                          pkey_split pkey_type  \
# 0                3          [conf, dft, SemiaoRVSTT07]      conf
# 1                3           [conf, dagstuhl, Caire07]      conf
# 2                3               [journals, tit, BT07]  journals
# 3                3  [conf, icdcsw, Pardo-Castellote03]      conf
# 4                3     [journals, corr, abs-0911-4329]  journals
# ...            ...                                 ...       ...
# 17160            3             [journals, tcs, ShiY08]  journals
# 17161            3               [conf, ijcai, TanC01]      conf
# 17162            3           [conf, hicss, NewellSW04]      conf
# 17163            3      [journals, sttt, HendriksNV06]  journals
# 17164            3    [conf, asplos, MagenheimerPPZ87]      conf
#
#               pkey_author match_titleKey   match_authorKey ptitle_lg
# 0           SemiaoRVSTT07             ia            Semiao        en
# 1                 Caire07              r             Caire        en
# 2                    BT07                                B        en
# 3      Pardo-Castellote03             te  Pardo-Castellote        en
# 4           abs-0911-4329             ab                 -        tl
# ...                   ...            ...               ...       ...
# 17160              ShiY08            Shi                 i        en
# 17161              TanC01              a               Tan        en
# 17162          NewellSW04              e            Newell        en
# 17163        HendriksNV06              d          Hendriks        en
# 17164    MagenheimerPPZ87             er       Magenheimer        en
#
# [17165 rows x 23 columns]

# %% [markdown]
# # Inspect ptype_id and pkey_type
#
# **ptype_id**
# - *article* = A paper that has been published in conference proceedings. The usage of conference and inproceedings is the same
# - *book* = A thesis written for the PhD level degree.
# - *incollection* = A titled section of a book. Such as a short story within the larger collection of short stories that make up the book
# - *inproceedings* = A paper that has been published in conference proceedings. The usage of conference and inproceedings is the same
# - *phdthesis* = A thesis written for the PhD level degree.
#
# **pkey_type**
# - *conf* =
# - *journals* =
# - *reference* =
# - *series* = could be series of books
# - *tr* = technical report -> An institutionally published report such as a report from a school, a government organization, an organization, or a company. This entry type is also frequently used for white papers and working papers.
# - *phd* = should likely be a phdthesis

# %%
df.groupby(by=['ptype_id','pkey_type']).size().reset_index()
# Out:
#          ptype_id  pkey_type     0
# 0         article       conf   490
# 1         article   journals  4477
# 2         article  reference     2
# 3         article     series     1
# 4         article         tr     9
# 5            book      books     4
# 6            book       conf     2
# 7            book   journals     1
# 8            book     series     4
# 9    incollection      books    21
# 10   incollection       conf   126
# 11   incollection   journals   351
# 12   incollection  reference    35
# 13   incollection     series    37
# 14  inproceedings      books     3
# 15  inproceedings       conf  9229
# 16  inproceedings   journals  1252
# 17  inproceedings  reference     5
# 18  inproceedings     series     5
# 19  inproceedings         tr     2
# 20      phdthesis       conf  1107
# 21      phdthesis   journals     1
# 22      phdthesis        phd     1

# %%
df.groupby(by=['pkey_type', 'ptype_id']).size().reset_index()
# Out:
#     pkey_type       ptype_id     0
# 0       books           book     4
# 1       books   incollection    21
# 2       books  inproceedings     3
# 3        conf        article   490
# 4        conf           book     2
# 5        conf   incollection   126
# 6        conf  inproceedings  9229
# 7        conf      phdthesis  1107
# 8    journals        article  4477
# 9    journals           book     1
# 10   journals   incollection   351
# 11   journals  inproceedings  1252
# 12   journals      phdthesis     1
# 13        phd      phdthesis     1
# 14  reference        article     2
# 15  reference   incollection    35
# 16  reference  inproceedings     5
# 17     series        article     1
# 18     series           book     4
# 19     series   incollection    37
# 20     series  inproceedings     5
# 21         tr        article     9
# 22         tr  inproceedings     2
